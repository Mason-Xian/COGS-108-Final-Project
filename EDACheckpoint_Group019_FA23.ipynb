# %% [markdown]
# **If you lost points on the last checkpoint you can get them back by responding to TA/IA feedback**
#
# Update/change the relevant sections where you lost those points, make sure you respond on GitHub Issues to your TA/IA to call their attention to the changes you made here.
#
# Please update your Timeline... no battle plan survives contact with the enemy, so make sure we understand how your plans have changed.

# %% [markdown]
# # COGS 108 - EDA Checkpoint

# %% [markdown]
# # Names
#
# - Bryce Beeson
# - Minghao Xian
# - Zeying Du
# - Bryant Quijada
# - Yasamin Mazaheri

# %% [markdown]
# # Research Question

# %% [markdown]
# In 2022, how does the effectiveness of telemedicine in providing mental health care and therapy compare to traditional in-person sessions?
# - The operational definition of “the effectiveness of telemedicine in providing mental health care and therapy” is patient satisfaction scores on surveys

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# The landscape of mental health care has undergone significant transformations, particularly with the increasing acceptance of therapy and the burgeoning adoption of telehealth, intensified by the COVID-19 pandemic. This shift has prompted several studies to scrutinize the comparative effectiveness of virtual therapy sessions against traditional in-person interventions.
#
# "In‐person versus virtual therapy in outpatient eating‐disorder treatment: A COVID‐19 inspired study" investigated the outcomes of individuals undergoing in-person and virtual therapy during the COVID-19 outbreak. Results indicated similar improvements in eating disorder symptoms, weight gain, and satisfaction with services in both groups<a name="cite_ref-5"></a>[<sup>5</sup>](#cite_note-5).
#
# Lee et al. explored the patient experience of telehealth services in a mental health setting during the COVID-19 pandemic, employing a cross-sectional survey conducted in an outpatient psychiatric clinic<a name="cite_ref-2"></a>[<sup>2</sup>](#cite_note-2). Their findings contribute valuable insights into how patients perceive telehealth services in mental health care.
#
# Comparing telehealth and face-to-face psychotherapy for less common mental health conditions, Greenwood et al. aimed to assess differences in effectiveness between the two treatment modalities<a name="cite_ref-1"></a>[<sup>1</sup>](#cite_note-1). This study sheds light on the nuances of treatment outcomes for less common mental health conditions.
#
# Polinski et al. delved into patient satisfaction and preferences with telehealth visits through a cross-sectional survey involving 1,734 patients<a name="cite_ref-3"></a>[<sup>3</sup>](#cite_note-3). The results underscore high patient satisfaction, with 94-99% reporting being "very satisfied" with various aspects of telehealth. Predictors of satisfaction included gender, overall understanding, quality of care, and convenience of telehealth.
#
# Kaur et al. explored patient satisfaction rates during the COVID-19 era, emphasizing the importance of communication methods in telemedicine<a name="cite_ref-4"></a>[<sup>4</sup>](#cite_note-4). The study found that satisfaction rates were higher when video calls were used for teleconsultations, signaling the significance of the mode of interaction in influencing patient satisfaction.
#
# Collectively, these studies suggest that telemedicine has the potential to be as effective as traditional in-person sessions for mental health care. The high satisfaction rates reported by patients further highlight the convenience and perceived quality of care associated with telehealth, contributing to improved accessibility to mental health services.
#
# Citations:
#
# 1. <a name="cite_note-1"></a> [^](#cite_ref-1) Greenwood, Hannah, et al. “Telehealth versus Face-to-Face Psychotherapy for Less Common Mental Health Conditions: Systematic Review and Meta-Analysis of Randomized Controlled Trials.” JMIR Mental Health, U.S. National Library of Medicine, 11 Mar. 2022, www.ncbi.nlm.nih.gov/pmc/articles/PMC8956990/.
# 2. <a name="cite_note-2"></a> [^](#cite_ref-2)Lee, Heeyoung, et al. “Patient Experience with Telehealth Service in a Mental Health Setting.” Archives of Psychiatric Nursing, U.S. National Library of Medicine, Apr. 2023, www.ncbi.nlm.nih.gov/pmc/articles/PMC10008765/.
# 3. <a name="cite_note-3"></a> [^](#cite_ref-3)Polinski, Jennifer M., et al. “Patients’ Satisfaction with and Preference for Telehealth Visits.” Journal of General Internal Medicine : JGIM, vol. 31, no. 3, 2016, pp. 269–75, https://doi.org/10.1007/s11606-015-3489-x.
# 4. <a name="cite_note-4"></a> [^](#cite_ref-4)Kaur, Karuna Nidhi, et al. “Patient Satisfaction for Telemedicine Health Services in the Era of COVID-19 Pandemic: A Systematic Review.” Frontiers in Public Health, vol. 10, 2022, pp. 1031867–1031867, https://doi.org/10.3389/fpubh.2022.1031867.
# 5. <a name="cite_note-5"></a> [^](#cite_ref-5)Steiger, Howard, et al. “In‐person Versus Virtual Therapy in Outpatient Eating‐disorder Treatment: A COVID‐19 Inspired Study.” International Journal of Eating Disorders, vol. 55, no. 1, 2022, pp. 145–50, https://doi.org/10.1002/eat.23655.

# %% [markdown]
# # Hypothesis

# %% [markdown]
# - In the year 2022, patients who have received their mental health care or therapy in person rated their level of satisfaction of the care they received differently from the patients who received their care remotely.
# - Our null hypothesis: patients who have received in-person or remote mental health care or therapy rated its  effectiveness based on the satisfaction of the care they received equally.
# - We think this will be the outcome because receiving mental health care remotely and in person are two different experiences. We think the difference in experiences will lead to differences in the effectiveness of the provided mental health care or therapy based on the satisfaction of the care they received.

# %% [markdown]
# # Data

# %% [markdown]
# - The Center for Behavioral Health Statistics and Quality (CBHSQ), Mental Health Client-Level Data (MH-CLD) and National Mental Health Services Survey (N-MHSS) are all reliable sources of data related to clinical mental health services, facilities, and treatments in the United States. Since datasets from those data collections cover wide time periods and are based on large national (the United States) and states-level samples, we think they are sufficient enough for our project.
# https://www.samhsa.gov/data/data-we-collect/n-sumhss-national-substance-use-and-mental-health-services-survey

# %% [markdown]
# ## Data Overview

# %% [markdown]
# After printing out our complete datasets, we've determined that there's no need for data wrangling. The datasets come from government websites, which usually means the data is reliable and well-organized. One clear sign of this is that we didn't come across any rows or columns completely missing data. The data looks clean and consistent, with no obvious formatting issues or irregularities or extra punctuations. In short, the quality of the data from these sources looks solid, so we can directly use it for our exploratory analysis.

# %% [markdown]
# ## SU63a OPIOIDS - Frequency of different types of health care facilities for opiods treatment

# %% [markdown]
# - https://github.com/COGS108/Group019_FA23/blob/master/csv/SU63a-opioids.csv
# - https://github.com/COGS108/Group019_FA23/blob/master/csv/SU63a-cont-opioids.csv
# - 54 observations
# - 14 variables
# - Description: The dataset comes from the National Substance Use and Mental Health Service Survey 2022: (N-SUMHSS) Annual Detailed Tables. The ‘Telemedicine/telehealth’ variable is the most important variable in this table. The datatype in this dataset is integer count. This metric can be proxy to the frequency in which people use telemedicine/telehealth to receive their mental health care or therapy. This data needs to be truncated down to only include the data we care about.

# %%
import pandas as pd

opioids_filepath = "csv-corrected/SU63a-opioids.csv"
cont_opioids_filepath = "csv-corrected/SU63a-cont-opioids.csv"

# Read the datasets into pandas DataFrames
opioids_data = pd.read_csv(opioids_filepath)
cont_opioids_data = pd.read_csv(cont_opioids_filepath)

# Set the display options to show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Display the entire table for each dataset
print("Opioids Dataset:")
opioids_data
# Out:
# Opioids Dataset:
#    State or jurisdiction1   Total2  Substance use counseling  \
# 0                   Total   14.854                    13.288
# 1                 Alabama  143.000                   130.000
# 2                  Alaska   83.000                    74.000
# 3                 Arizona  441.000                   374.000
# 4                Arkansas  138.000                    94.000
# 5              California    1.525                     1.368
# 6                Colorado  323.000                   254.000
# 7             Connecticut  174.000                   161.000
# 8                Delaware   51.000                    43.000
# 9    District of Columbia   28.000                    25.000
# 10                Florida  681.000                   610.000
# 11                Georgia  309.000                   255.000
# 12                 Hawaii  124.000                   113.000
# 13                  Idaho   97.000                    93.000
# ...

# %%
print("\nCont Opioids Dataset:")
cont_opioids_data
# Out:
# Cont Opioids Dataset:
#    State or jurisdiction1  Total2  Substance use counseling  \
# 0                  Nevada     112                        99
# 1           New Hampshire     105                       104
# 2              New Jersey     388                       374
# 3              New Mexico     142                       112
# 4                New York     826                       779
# 5          North Carolina     561                       481
# 6            North Dakota      64                        52
# 7                    Ohio     649                       596
# 8                Oklahoma     180                       141
# 9                  Oregon     220                       205
# 10           Pennsylvania     522                       499
# 11            Puerto Rico      72                        67
# 12           Rhode Island      59                        48
# 13         South Carolina     107                       101
# ...

# %% [markdown]
# ## SU63b OPIOIDS - Frequency of different types of health care facilities for other drugs treatment

# %% [markdown]
# - https://github.com/COGS108/Group019_FA23/blob/master/csv/SU63b-opioids.csv
# - https://github.com/COGS108/Group019_FA23/blob/master/csv/SU63b-cont-opioids.csv
# - 54 observations
# - 14 variables
# - Description: The dataset comes from the National Substance Use and Mental Health Service Survey (N-SUMHSS) 2022: Annual Detailed Tables. The ‘Telemedicine/telehealth’ variable is the most important variable in this table. The datatype in this dataset is percent distribution. This metric can be proxy to the frequency in which people use telemedicine/telehealth to receive their mental health care or therapy. This data needs to be truncated down to only include the data we care about.

# %%
import pandas as pd

# Define the URLs for the datasets
opioids_url_b = "csv-corrected/SU63b-opioids-revised.csv"
cont_opioids_url_b = "csv-corrected/SU63b-opioids-cont-revised.csv"

# Read the datasets into pandas DataFrames
opioids_data_b = pd.read_csv(opioids_url_b)
cont_opioids_data_b = pd.read_csv(cont_opioids_url_b)

# Display basic information about the datasets
print("Opioids Dataset B:")
opioids_data_b
# Out:
# Opioids Dataset B:
#    State or jurisdiction1  Number of facilities  Substance use counseling  \
# 0                   Total                 14854                      89.5
# 1                 Alabama                   143                      90.9
# 2                  Alaska                    83                      89.2
# 3                 Arizona                   441                      84.8
# 4                Arkansas                   138                      68.1
# 5              California                  1525                      89.7
# 6                Colorado                   323                      78.6
# 7             Connecticut                   174                      92.5
# 8                Delaware                    51                      84.3
# 9    District of Columbia                    28                      89.3
# 10                Florida                   681                      89.6
# ...

# %%
print("\nCont Opioids Dataset B:")
cont_opioids_data_b
# Out:
# Cont Opioids Dataset B:
#    State or jurisdiction  Number of facilities  Substance use counseling  \
# 0                 Nevada                   112                      88.4
# 1          New Hampshire                   105                      99.0
# 2             New Jersey                   388                      96.4
# 3             New Mexico                   142                      78.9
# 4               New York                   826                      94.3
# 5         North Carolina                   561                      85.7
# 6           North Dakota                    64                      81.3
# 7                   Ohio                   649                      91.8
# 8               Oklahoma                   180                      78.3
# 9                 Oregon                   220                      93.2
# 10          Pennsylvania                   522                      95.6
# ...

# %% [markdown]
# ## SU63a - Other Drugs - Percentage of different types of health care facilities for opiods treatment

# %% [markdown]
# - https://github.com/COGS108/Group019_FA23/blob/master/csv/SU63a-other.csv
# - https://github.com/COGS108/Group019_FA23/blob/master/csv/SU63a-cont-other.csv
# - 54 observations
# - 14 variables
# - Description: The dataset comes from the National Substance Use and Mental Health Service Survey (N-SUMHSS) 2022: Annual Detailed Tables. The ‘Telemedicine/telehealth’ variable is the most important variable in this table. The datatype in this dataset is integer count. This metric can be proxy to the frequency in which people use telemedicine/telehealth to receive their mental health care or therapy. This data needs to be truncated down to only include the data we care about.

# %%
import pandas as pd

# Define the URLs for the datasets
other_drugs_url_a = "csv-corrected/SU63a-other.csv"
cont_other_drugs_url_a = "csv-corrected/SU63a-cont-other.csv"

# Read the datasets into pandas DataFrames
other_drugs_data_a = pd.read_csv(other_drugs_url_a)
cont_other_drugs_data_a = pd.read_csv(cont_other_drugs_url_a)

# Display basic information about the datasets
print("Other Drugs Dataset A:")
other_drugs_data_a
# Out:
# Other Drugs Dataset A:
#    State or jurisdiction1  Total2  Substance use counseling  \
# 0                   Total   14854                     12960
# 1                 Alabama     143                       124
# 2                  Alaska      83                        74
# 3                 Arizona     441                       373
# 4                Arkansas     138                       107
# 5              California    1525                      1364
# 6                Colorado     323                       288
# 7             Connecticut     174                       157
# 8                Delaware      51                        42
# 9    District of Columbia      28                        24
# 10                Florida     681                       597
# 11                Georgia     309                       253
# 12                 Hawaii     124                       118
# 13                  Idaho      97                        95
# ...

# %%
print("\nCont Other Drugs Dataset A:")
cont_other_drugs_data_a
# Out:
# Cont Other Drugs Dataset A:
#    State or jurisdiction1  Total2  Substance use counseling  \
# 0                  Nevada     112                      91.1
# 1           New Hampshire     105                      84.8
# 2              New Jersey     388                      91.8
# 3              New Mexico     142                      74.6
# 4                New York     826                      90.2
# 5          North Carolina     561                      78.8
# 6            North Dakota      64                      90.6
# 7                    Ohio     649                      90.0
# 8                Oklahoma     180                      91.1
# 9                  Oregon     220                      92.7
# 10           Pennsylvania     522                      90.8
# 11            Puerto Rico      72                      90.3
# 12           Rhode Island      59                      76.3
# 13         South Carolina     107                      77.6
# ...

# %% [markdown]
# ## SU63b Other Drugs - Percentage of different types of health care facilities for other drugs treatment

# %% [markdown]
# - https://github.com/COGS108/Group019_FA23/blob/master/csv/SU63b-other.csv
# - https://github.com/COGS108/Group019_FA23/blob/master/csv/SU63b-cont-other.csv
# - 54 observations
# - 14 variables
# - Description: The dataset comes from the National Substance Use and Mental Health Service Survey (N-SUMHSS) 2022: Annual Detailed Tables. The ‘Telemedicine/telehealth’ variable is the most important variable in this table. The datatype in this dataset is percent distribution. This metric can be proxy to the frequency in which people use telemedicine/telehealth to receive their mental health care or therapy. This data needs to be truncated down to only include the data we care about.

# %%
import pandas as pd

# Define the URLs for the datasets
other_drugs_url_b = "csv-corrected/SU63b-other.csv"
cont_other_drugs_url_b = "csv-corrected/SU63b-cont-other.csv"

# Read the datasets into pandas DataFrames
other_drugs_data_b = pd.read_csv(other_drugs_url_b)
cont_other_drugs_data_b = pd.read_csv(cont_other_drugs_url_b)

# Display basic information about the datasets
print("Other Drugs Dataset B:")
other_drugs_data_b
# Out:
# Other Drugs Dataset B:
#    State or jurisdiction1  Number of facilities  Substance use counseling  \
# 0                   Total                 14854                      87.2
# 1                 Alabama                   143                      86.7
# 2                  Alaska                    83                      89.2
# 3                 Arizona                   441                      84.6
# 4                Arkansas                   138                      77.5
# 5              California                  1525                      89.4
# 6                Colorado                   323                      89.2
# 7             Connecticut                   174                      90.2
# 8                Delaware                    51                      82.4
# 9    District of Columbia                    28                      85.7
# 10                Florida                   681                      87.7
# ...

# %%
print("\nCont Other Drugs Dataset B:")
cont_other_drugs_data_b
# Out:
# Cont Other Drugs Dataset B:
#                           State or jurisdiction  Number  \
# Nevada               112                   91.1    54.5
# New Hampshire        105                   84.8    27.6
# New Jersey           388                   91.8    56.2
# New Mexico           142                   74.6    29.6
# New York             826                   90.2    43.9
# North Carolina       561                   78.8    36.4
# North Dakota         64                    90.6    51.6
# Ohio                 649                   90.0    44.5
# Oklahoma             180                   91.1    36.7
# Oregon               220                   92.7    44.5
# Pennsylvania         522                   90.8    55.0
# Puerto Rico          72                    90.3    13.9
# Rhode Island         59                    76.3    39.0
# South Carolina       107                   77.6    29.0
# South Dakota         51                    90.2    56.9
# ...

# %% [markdown]
# ## MH21a - Mental health facilities’ client satisfaction survey by facility type with numbers

# %% [markdown]
# - https://github.com/COGS108/Group019_FA23/blob/master/csv/MH21a.csv
# - 16 observations
# - 8 variables
# - Description: The dataset comes from the National Substance Use and Mental Health Service Survey (N-SUMHSS) 2022: Annual Detailed Tables. The periodic client satisfaction surveys variable is the most important variable in this table. The datatype in this dataset is integer count. This metric can be proxy to the patients’ own rating for the satisfaction and effectiveness for the care that they received. This data needs to be truncated down to only include the data we care about.

# %%
import pandas as pd

# Define the URL for the dataset
mh21a_url = "csv-corrected/MH21a.csv"

# Read the dataset into a pandas DataFrame
mh21a_data = pd.read_csv(mh21a_url)

# Display basic information about the dataset
print("MH21a Dataset:")
mh21a_data
# Out:
# MH21a Dataset:
#                                        Facility type  Total  \
# 0                                              Total   9586
# 1                      Psychiatric hospitals (Total)    448
# 2                     Psychiatric hospitals (Public)    119
# 3                    Psychiatric hospitals (Private)    329
# 4                                  General hospitals    618
# 5                                    State hospitals     33
# 6                                  RTCs for children    448
# 7                                    RTCs for adults    699
# 8    Other types of residential treatment facilities     75
# 9                   Veterans Affairs medical centers    393
# 10                   Community mental health centers   1835
# 11     Certified community behavioral health clinics    481
# 12  Partial hospitalization/day treatment facilities    334
# 13               Outpatient mental health facilities   3516
# ...

# %% [markdown]
# ## MH21b - Mental health facilities’ client satisfaction survey by facility type with percentage

# %% [markdown]
# - https://github.com/COGS108/Group019_FA23/blob/master/csv/MH21b.csv
# - 16 observations
# - 8 variables
# - Description: The dataset comes from the National Substance Use and Mental Health Service Survey (N-SUMHSS)  2022: Annual Detailed Tables. The periodic client satisfaction surveys variable is the most important variable in this table. The datatype in this dataset is percent distribution. This metric can be proxy to the patients’ own rating for the satisfaction and effectiveness for the care that they received. This data needs to be truncated down to only include the data we care about.

# %%
import pandas as pd

# Define the URL for the dataset
mh21b_url = "csv-corrected/MH21b.csv"

# Read the dataset into a pandas DataFrame
mh21b_data = pd.read_csv(mh21b_url)

# Display basic information about the dataset
print("MH21b Dataset:")
mh21b_data
# Out:
# MH21b Dataset:
#                                        Facility type  \
# 0                                              Total
# 1                      Psychiatric hospitals (Total)
# 2                      Psychiatric hospitals (Public
# 3                    Psychiatric hospitals (Private)
# 4                                  General hospitals
# 5                                    State hospitals
# 6                                  RTCs for children
# 7                                    RTCs for adults
# 8    Other types of residential treatment facilities
# 9                   Veterans Affairs medical centers
# 10                   Community mental health centers
# 11     Certified community behavioral health clinics
# 12  Partial hospitalization/day treatment facilities
# 13               Outpatient mental health facilities
# 14            Multi-setting mental health facilities
# 15                                             Other
#
#     Total number of facilities  \
# ...

# %% [markdown]
# ## SU19 - Substance facilities by frequently used methods and facility type

# %% [markdown]
# - https://github.com/COGS108/Group019_FA23/blob/master/csv/SU19.csv
# - 15 observations
# - 6 variables
# - Description: The dataset comes from the National Substance Use and Mental Health Service Survey (N-SUMHSS) 2022: Annual Detailed Tables. The periodic client satisfaction surveys variable is the most important observation in this table. The datatype in this dataset is integer count. This metric tells us about how many cases of mental health care is done via telemedicine.

# %%
import pandas as pd

# Define the URL for the dataset
su19_url = "csv-corrected/SU19.csv"

# Read the dataset into a pandas DataFrame
su19_data = pd.read_csv(su19_url)

# Display basic information about the dataset
print("SU19 Dataset:")
su19_data
# Out:
# SU19 Dataset:
#                                                     Clinical/therapeutic approaches:  \
# Total                                                                          14854
# Substance use counseling                                                       14135
# 12-step facilitation                                                            7335
# Brief intervention                                                              9958
# Cognitive behavioral therapy                                                   12973
# Contingency management/motivational incentives                                  6645
# Motivational interviewing                                                      13135
# Trauma-related counseling                                                      11457
# Anger management                                                                9779
# Matrix model                                                                    6018
# ...

# %% [markdown]
# ## MH14a - Mental health facilities that offer different treatment modalities

# %% [markdown]
# - https://github.com/COGS108/Group019_FA23/blob/master/csv/MH14a.csv
# - https://github.com/COGS108/Group019_FA23/blob/master/csv/MH14a-cont.csv
# - 16 observations
# - 8 variables
# - Description: The dataset comes from the National Substance Use and Mental Health Service Survey (N-SUMHSS) 2022: Annual Detailed Tables. The ‘Periodic client satisfaction surveys’ variable is the most important variable in the dataset. The datatype in this dataset is integer count. This metric can be proxy to the patients’ own rating for the satisfaction and effectiveness for the care that they received. This data needs to be truncated down to only include the data we care about.

# %%
import pandas as pd

# Define the URLs for the datasets
mh14a_url = "csv-corrected/MH14a.csv"
cont_mh14a_url = "csv-corrected/MH14a-cont.csv"

# Read the datasets into pandas DataFrames
mh14a_data = pd.read_csv(mh14a_url)
cont_mh14a_data = pd.read_csv(cont_mh14a_url)

# Display basic information about the datasets
print("MH14a Dataset:")
mh14a_data
# Out:
# MH14a Dataset:
#                                        Facility type  Total  \
# 0                                              Total   9586
# 1                              Psychiatric hospitals    448
# 2                                             Public    119
# 3                                            Private    329
# 4                                General hospitals 2    618
# 5                                    State hospitals     33
# 6                                  RTCs for children    448
# 7                                    RTCs for adults    699
# 8    Other types of residential treatment facilities     75
# 9                   Veterans Affairs medical centers    393
# 10                   Community mental health centers   1835
# 11     Certified community behavioral health clinics    481
# 12  Partial hospitalization/day treatment facilities    334
# 13               Outpatient mental health facilities   3516
# ...

# %%
print("\nCont MH14a Dataset:")
cont_mh14a_data
# Out:
# Cont MH14a Dataset:
#                                        Facility type  Total  \
# 0                                              Total   9586
# 1                              Psychiatric hospitals    448
# 2                                             Public    119
# 3                                            Private    329
# 4                                  General hospitals    618
# 5                                    State hospitals     33
# 6                                  RTCs for children    448
# 7                                    RTCs for adults    699
# 8    Other types of residential treatment facilities     75
# 9                   Veterans Affairs medical centers    393
# 10                   Community mental health centers   1835
# 11     Certified community behavioral health clinics    481
# 12  Partial hospitalization/day treatment facilities    334
# 13               Outpatient mental health facilities   3516
# ...

# %% [markdown]
# # Characteristics associated with patient preference

# %% [markdown]
# - https://github.com/COGS108/Group019_FA23/blob/master/csv/Characteristics associated with patient preference-clean.csv
# - ?? observations
# - ? variables
# - Description: to be filled in

# %%
import pandas as pd

# Define the URLs for the datasets
Characteristics_url = "csv-corrected/Characteristics associated with patient preference-clean.csv"

# Read the datasets into pandas DataFrames
char_pref = pd.read_csv(Characteristics_url)

# Display basic information about the datasets
print("char_pref Dataset:")
char_pref
# Out:
# char_pref Dataset:
#    Table 3 Characteristics associated with patientpreference for telehealth visits compared to traditional visits \n  \
# 0                                                 NaN
# 1                                     Age 18–34 years
# 2                                     Age 35–44 years
# 3                              Age 45 years and older
# 4                                       Female gender
# 5                 Have a primary care\nprovider (PCP)
# 6                      Do not have medical\ninsurance
# 7                   Concerns about using\ntelehealtha
# 8   Found telehealth format to\nbe confusing or\nc...
# 9   Overall understanding of\nthe telehealth servicec
# 10  Ease of seeing diagnostic\nimages on the monitorc
# 11  Ease of seeing and hearing\nthe remote practit...
# 12                 Capability of the assisting\nnurse
# 13              Quality of the health care\nreceivedc
# 14  Treatment plan and patient\neducational materi...
# ...

# %% [markdown]
# # Factors Affecting Patient's Satisfaction with Telemedicine

# %% [markdown]
# - https://github.com/COGS108/Group019_FA23/blob/master/csv/Factors Affecting Patient's Satisfaction with Telemedicine-clean.csv
# - ?? observations
# - ? variables
# - Description: to be filled in

# %%
import pandas as pd

# Define the URLs for the datasets
factors_url = "csv-corrected/Factors Affecting Patient's Satisfaction with Telemedicine-clean.csv"

# Read the datasets into pandas DataFrames
factors_affect_sat = pd.read_csv(factors_url)

# Display basic information about the datasets
print("factors_affect_sat Dataset:")
factors_affect_sat
# Out:
# factors_affect_sat Dataset:
#                                            Unnamed: 0  \
# 0                                                 NaN
# 1                                              Gender
# 2                                                 NaN
# 3                                           Age group
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                   Educational level
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13  Do you have stable internet to support your ac...
# 14                                                NaN
# 15                                                NaN
# ...

# %% [markdown]
# # Opinions about Telemedicine Experience

# %% [markdown]
# - https://github.com/COGS108/Group019_FA23/blob/master/csv/Opinions about Telemedicine Experience-clean.csv
# - ?? observations
# - ? variables
# - Description: to be filled in

# %%
import pandas as pd

# Define the URLs for the datasets
opinions_url = "csv-corrected/Opinions about Telemedicine Experience-clean.csv"

# Read the datasets into pandas DataFrames
opinions_tele = pd.read_csv(opinions_url)

# Display basic information about the datasets
print("opinions_tele Dataset:")
opinions_tele
# Out:
# opinions_tele Dataset:
#                                            Unnamed: 0         Unnamed: 1  \
# 0         I can easily talk to my healthcare provider     Strongly agree
# 1                                                 NaN              Agree
# 2                                                 NaN            Neutral
# 3                                                 NaN           Disagree
# 4                                                 NaN  Strongly disagree
# 5           I can hear my healthcare provider clearly     Strongly agree
# 6                                                 NaN              Agree
# 7                                                 NaN            Neutral
# 8                                                 NaN           Disagree
# 9                                                 NaN  Strongly disagree
# 10  My healthcare provider is able to understand m...     Strongly agree
# ...

# %% [markdown]
# # Patient_Satisfaction_Review

# %% [markdown]
# - https://github.com/COGS108/Group019_FA23/blob/master/csv/Patient_Satisfaction_Review.csv
# - ?? observations
# - ? variables
# - Description: to be filled in

# %%
import pandas as pd

# Define the URLs for the datasets
patient_sat_url = "csv-corrected/Patient_Satisfaction_Review.csv"

# Read the datasets into pandas DataFrames
patient_sat = pd.read_csv(patient_sat_url)

# Display basic information about the datasets
print("patient_sat Dataset:")
patient_sat
# Out:
# patient_sat Dataset:
#      Name of author                                     Title of study  Year  \
# 0     Noceda et al.  The patient satisfaction with telemedicine in ...  2022
# 1      Gupta et al.  Patients  experience of telemedicine during co...  2021
# 2      Nasser et al  Measuring the patients’ satisfaction about  te...  2021
# 3     Sharma et al.  Views and perception on telemedicine by consum...  2021
# 4   Al-Sharifet al.  Telehealth to the rescue during covid-19: a co...  2021
# 5    Orrange et al.  Patient satisfaction and trust in telemedicine...  2021
# 6    Jannati et al.  A cross-sectional online survey on patient’s s...  2021
# 7  Ramaswamy et al.  Patient satisfaction with telemedicine during ...  2020
#
#                         Study design    Age (years)  Sample size  \
# 0    Explanatory mixed method design          18-65          200
# 1              Cross sectional study            ≥18          462
# ...

# %% [markdown]
# # Patients' motivations for and satisfaction with telehealth visits

# %% [markdown]
# - https://github.com/COGS108/Group019_FA23/blob/master/csv/Patients' motivations for and satisfaction with telehealth visits-clean.csv
# - ?? observations
# - ? variables
# - Description: to be filled in

# %%
import pandas as pd

# Define the URLs for the datasets
patient_motivation_url = "csv-corrected/Patients' motivations for and satisfaction with telehealth visits-clean.csv"

# Read the datasets into pandas DataFrames
patient_motivation = pd.read_csv(patient_motivation_url)

# Display basic information about the datasets
print("patient_motivation Dataset:")
patient_motivation
# Out:
# patient_motivation Dataset:
#    Table 2 Patients’ motivations for and satisfaction with telehealth visits among all patients and among those who rated telehealth as good or better than a traditional office visit  \
# 0             Primary motivation for using telehealth
# 1                             Shorter or no wait time
# 2                                           Curiosity
# 3                                            Concerns
# 4                   Concerns about using telehealth b
# 5   Found telehealth format to be confusing or com...
# 6   Patients reporting that they were “very satisf...
# 7     Overall understanding of the telehealth service
# 8     Ease of seeing diagnostic images on the monitor
# 9   Ease of seeing and hearing the remote practiti...
# 10                  Capability of the assisting nurse
# 11                Quality of the health care received
# 12  Treatment plan and patient educational materia...
# ...

# %% [markdown]
# ## Results

# %% [markdown]
# ### Exploratory Data Analysis
# Carry out whatever EDA you need to for your project. Because every project will be different we can't really give you much of a template at this point. But please make sure you describe the what and why in text here as well as providing interpretation of results and context.

# %% [markdown]
# ### SU63a Opiod Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the dataset
filepath = "csv-corrected/SU63a-opioids.csv"
cont_opioids_filepath = "csv-corrected/SU63a-cont-opioids.csv"

opioids_data = pd.read_csv(filepath, skiprows=2)
cont_opioids_data = pd.read_csv(cont_opioids_filepath, skiprows=1)

# Select the relevant columns for the plot using index positions
states_opioids = opioids_data.iloc[:, 0]
telehealth_values_opioids = opioids_data.iloc[:, 13]

states_cont_opioids = cont_opioids_data.iloc[:, 0]
telehealth_values_cont_opioids = cont_opioids_data.iloc[:, 13]

# Plotting
plt.figure(figsize=(12, 6))
plt.bar(states_opioids, telehealth_values_opioids, color='green')
plt.bar(states_cont_opioids, telehealth_values_cont_opioids, color='green')

plt.title('Usage of Telehealth in Substance Use Treatment Facilities by State')
plt.xlabel('State or jurisdiction')
plt.ylabel('Number of Facilities Using Telehealth')
plt.xticks(rotation=90)  # Rotate x-axis labels for better visibility
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# From this graph we can see that California has more facilities that provide telehealth counseling. But does this mean California is more likely to provide care in the form of telehealth? In order to find the answer, we need to look at the percentage of care provided that is telehealth, instead of simply count.

# %% [markdown]
# ### SU63b Opiod Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the dataset
filepath = "csv-corrected/SU63b-opioids-revised.csv"
cont_opioids_filepath = "csv-corrected/SU63b-opioids-cont-revised.csv"

opioids_data = pd.read_csv(filepath, skiprows=2)
cont_opioids_data = pd.read_csv(cont_opioids_filepath, skiprows=1)

# Select the relevant columns for the plot using index positions
states_opioids = opioids_data.iloc[:, 0]
telehealth_values_opioids = opioids_data.iloc[:, 13]

states_cont_opioids = cont_opioids_data.iloc[:, 0]
telehealth_values_cont_opioids = cont_opioids_data.iloc[:, 13]

# Plotting
plt.figure(figsize=(12, 6))
plt.bar(states_opioids, telehealth_values_opioids, color='green')
plt.bar(states_cont_opioids, telehealth_values_cont_opioids, color='green')

plt.title('Usage of Telehealth in Substance Use Treatment Facilities by State')
plt.xlabel('State or jurisdiction')
plt.ylabel('Number of Facilities Using Telehealth')
plt.xticks(rotation=90)  # Rotate x-axis labels for better visibility
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# From this graph we can get a better grasp on which states are more keen on providing care through telehealth. It turns out California actually isn't the state with the highest percentage of teleheath care provided. That title goes to Wyoming. We can also see that Puerto Rico provides the lowest percentage of telehealth in the country.
#
# Next, we want to find out if providing more telehealth actually help with the care provided. We can use the number of relapse prevention cases as a metric to answer that question.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the dataset
filepath = "csv-corrected/SU63a-opioids.csv"
cont_opioids_filepath = "csv-corrected/SU63a-cont-opioids.csv"

opioids_data = pd.read_csv(filepath, skiprows=2)
cont_opioids_data = pd.read_csv(cont_opioids_filepath, skiprows=1)

# Select relevant columns for the analysis using index positions
telehealth_values_opioids = opioids_data.iloc[:, 13]
relapse_prevention_values_opioids = opioids_data.iloc[:, -2]

telehealth_values_cont_opioids = cont_opioids_data.iloc[:, 13]
relapse_prevention_values_cont_opioids = cont_opioids_data.iloc[:, -2]

# Plotting
plt.figure(figsize=(12, 6))

# Scatter plot for Opioids
plt.scatter(telehealth_values_opioids, relapse_prevention_values_opioids, color='blue', label='Opioids')
# Scatter plot for Cont Opioids
plt.scatter(telehealth_values_cont_opioids, relapse_prevention_values_cont_opioids, color='green', label='Cont Opioids', alpha=0.7)

plt.title('Usage of Telehealth vs Success Judged by Relapse Prevention')
plt.xlabel('Number of Facilities Using Telehealth')
plt.ylabel('Relapse Prevention Values')
plt.legend()
plt.grid(True)
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# As it turns out, state with more facilities that provide telehealth also have more cases of relapse prevention.

# %%
by_age = char_pref.iloc[1:4]
#save age information into a new data frame
by_age.replace("Reference group", "1.00", inplace=True)
#replace the text "Reference group" with "1.00"

by_age = by_age.rename(columns={'Unnamed: 1': 'Preferred', 'Unnamed: 2': 'Liked'})
#add column names to by_age
by_age['Preferred'] = by_age['Preferred'].str.extract(r'([\d.]+)')
by_age['Liked'] = by_age['Liked'].str.extract(r'([\d.]+)')
#get rid of confidence interval

by_age
# Out:
# C:\Users\bryce\AppData\Local\Temp\ipykernel_5272\1786610646.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   by_age.replace("Reference group", "1.00", inplace=True)
#   Table 3 Characteristics associated with patientpreference for telehealth visits compared to traditional visits \n  \
# 1                                    Age 18–34 years
# 2                                    Age 35–44 years
# 3                             Age 45 years and older
#
#   Preferred Liked
# 1      0.92  0.92
# 2      1.00  1.00
# 3      1.05  0.60

# %%
import matplotlib.pyplot as plt

by_age['Preferred'] = pd.to_numeric(by_age['Preferred'])  
by_age['Liked'] = pd.to_numeric(by_age['Liked'])  
# Convert entries to numeric if it's not already
bar_width = 0.35

# Create a figure and axis
plt.figure(figsize=(10, 6))
plt.bar(by_age.index - bar_width/2, by_age['Preferred'], bar_width, label='Preferred', color='skyblue')
plt.bar(by_age.index + bar_width/2, by_age['Liked'], bar_width, label='Liked', color='salmon')


# Set plot labels and title
plt.xticks(by_age.index, by_age.iloc[:, 0], rotation=45) 
plt.title('Preference/Like for telehealth, by age')
plt.xlabel('Age')  
plt.ylabel('Odds ratio')

# Show the plot
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# From the graph we can see how age affected the patients' preference to telemedicine. We a see that preference for telemedicine in patients from 18-34 years old and patients from 35-44 years old are roughly equal, while although patients 45 years and older have roughly the same odds to prefer telemedicine, they only have 60% odds to like it.

# %%
med_care = char_pref.iloc[5:7]
#save med care information into a new data frame

char_pref = char_pref.rename(columns={'Unnamed: 1': 'Preferred', 'Unnamed: 2': 'Liked'})
#add column names to char_pref
med_care['Preferred'] = med_care['Preferred'].str.extract(r'([\d.]+)')
med_care['Liked'] = med_care['Liked'].str.extract(r'([\d.]+)')
med_care
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\bryce\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Users\bryce\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\bryce\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Preferred'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
med_care['Preferred'] = pd.to_numeric(med_care['Preferred'])  
med_care['Liked'] = pd.to_numeric(med_care['Liked'])  
# Convert entries to numeric if it's not already

# Create a figure and axis
plt.figure(figsize=(10, 6))
plt.bar(med_care.index - bar_width/2, med_care['Preferred'], bar_width, label='Preferred', color='green')
plt.bar(med_care.index + bar_width/2, med_care['Liked'], bar_width, label='Liked', color='purple')


# Set plot labels and title
plt.xticks(med_care.index, med_care.iloc[:, 0], rotation=45) 
plt.title('Preference/Like for telehealth, by med care availability')
plt.xlabel('Med care availability')  
plt.ylabel('Odds ratio')

# Show the plot
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\bryce\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Users\bryce\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\bryce\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Preferred'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# From the graph we can see how med care availability affected the patients' preference to telemedicine. We a see that patients who do not have medical insurance both prefer and like telemedine more than patients who have a primary care provider. This might be caused by the comparably lower cost that comes with telemedicine.

# %%
other_char = char_pref.iloc[7:16]
#save other characteristics into a new data frame

other_char['Preferred'] = other_char['Preferred'].str.extract(r'([\d.]+)')
other_char['Liked'] = other_char['Liked'].str.extract(r'([\d.]+)')
other_char
# Out:
# /var/folders/by/g3tt5n_s46s6vrhqr7zhj06r0000gn/T/ipykernel_8907/18229735.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_char['Preferred'] = other_char['Preferred'].str.extract(r'([\d.]+)')
# /var/folders/by/g3tt5n_s46s6vrhqr7zhj06r0000gn/T/ipykernel_8907/18229735.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_char['Liked'] = other_char['Liked'].str.extract(r'([\d.]+)')
# ...

# %%
other_char['Preferred'] = pd.to_numeric(other_char['Preferred'])  
other_char['Liked'] = pd.to_numeric(other_char['Liked'])  
# Convert entries to numeric if it's not already

# Create a figure and axis
plt.figure(figsize=(10, 6))
plt.bar(other_char.index - bar_width/2, other_char['Preferred'], bar_width, label='Preferred', color='brown')
plt.bar(other_char.index + bar_width/2, other_char['Liked'], bar_width, label='Liked', color='grey')


# Set plot labels and title
plt.xticks(other_char.index, other_char.iloc[:, 0], rotation=45) 
plt.title('Preference/Like for telehealth, by other charisteristics')
plt.xlabel('characteristic')
plt.ylabel('Odds ratio')

# Show the plot
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# /var/folders/by/g3tt5n_s46s6vrhqr7zhj06r0000gn/T/ipykernel_8907/3575027523.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_char['Preferred'] = pd.to_numeric(other_char['Preferred'])
# /var/folders/by/g3tt5n_s46s6vrhqr7zhj06r0000gn/T/ipykernel_8907/3575027523.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_char['Liked'] = pd.to_numeric(other_char['Liked'])

# %% [markdown]
# From the graph we can see how how various other characteristics affected the patients' preference to telemedicine. Several points are notable:
#
# People who have concerns using telehealth, found the telehealth format confusing or complicated, and are satisfied with the capability of their assisting nurse have notably lower preference for telehealth. The first two are to be expected. We suspect that people felt that the format of telehealth hindered the capability of their nurses. In other words, patients might have felt that the capability of their assisting nurses could be better utilized in a tradditional setting.
#
# People who have a better overall understanding of telehealth, are more satisfied with the quality of the care they received, are more satisfied with the treatment plan and patient\neducational material received, are more satisfied with the convenience of using telehealth are significantly more likelu to like telehealth. This is to be expected.

# %% [markdown]
# ### Factors Affecting Patient's Satisfaction with Telemedicine - Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the dataset
factors_url = "csv-corrected/Factors Affecting Patient's Satisfaction with Telemedicine-clean.csv"
factors_affect_sat = pd.read_csv(factors_url)

# Select the relevant rows for the plot using index positions
factors_affect_sat_values = factors_affect_sat.iloc[17:30, 1:7]
factors_affect_sat_values = factors_affect_sat_values.rename(columns={'Unnamed: 1': 'Health Clinic'})
print(factors_affect_sat_values)

# Select the relevant columns for the plot using index positions
plt.figure(figsize=(10, 6))
plt.bar(factors_affect_sat_values.index - 1.5/5, factors_affect_sat_values.iloc[:, 1], width = 0.15, label='Strongly agree', color='blue')
plt.bar(factors_affect_sat_values.index - 0.75/5, factors_affect_sat_values.iloc[:, 2], width = 0.15, label='Agree', color='green')
plt.bar(factors_affect_sat_values.index - 0/5, factors_affect_sat_values.iloc[:, 3], width = 0.15, label='Neutral', color='grey')
plt.bar(factors_affect_sat_values.index + 0.75/5, factors_affect_sat_values.iloc[:, 4], width = 0.15, label='Disagree', color='orange')
plt.bar(factors_affect_sat_values.index + 1.5/5, factors_affect_sat_values.iloc[:, 5], width = 0.15, label='Strongly disagree', color='red')

# Plotting
plt.xticks(factors_affect_sat_values.index, factors_affect_sat_values.iloc[:, 0], rotation=90)
plt.title('Overall, I am satisfied with the quality of service being provided via telemedicine')
plt.xlabel('Health Clinic')
plt.ylabel('Percentage of Satisfaction Choice')

# Show the plot
plt.legend()
plt.tight_layout()
plt.show()
# Out:
#                 Health Clinic  \
# 17          Strongly disagree
# 18                   Internal
# 19               Rheumatology
# 20                    Urology
# 21                 Hematology
# 22  Obstetrics and gynecology
# 23           Gastrointestinal
# 24                  Pediatric
# 25                  Endocrine
# 26                 Cardiology
# 27                Dermatology
# 28                 Orthopedic
# 29                 Psychiatry
#
#      Overall, I am satisfied with the quality of service being provided via telemedicine.  \
# 17                                                  0
# 18                                              0.333
# 19                                              0.333
# 20                                              0.286
# 21                                              0.231
# 22                                              0.154
# 23                                              0.286
# 24                                                  0
# ...

# %% [markdown]
# From this graph, we can visualize the distribution of responses, based on percentage, whether patients from various health clinics strongly agree, agree, are neutral, disagree, or strongly disagree with the prompt that "Overall, I am satisfied with the quality of service being provided via telemedicine". Just by looking at the graph, we can see that most patients agree or are neutral with the prompt which implies that telemedicine is just as effective if not more effective than traditional in-person sessions for providing mental health care and therapy. However, this graph is not very clear, so in order to make a clearer conclusion, we need to take the average values of the different response choices from each Health Clinic and calculate the mean for each response choice.

# %% [markdown]
# ### Factors Affecting Patient's Satisfaction with Telemedicine Cont. - Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the dataset
factors_url = "csv-corrected/Factors Affecting Patient's Satisfaction with Telemedicine-clean.csv"
factors_affect_sat = pd.read_csv(factors_url)

# Select the relevant rows for the plot using index positions
factors_affect_sat_values = factors_affect_sat.iloc[17:30, 1:7]
factors_affect_sat_values = factors_affect_sat_values.rename(columns={'Unnamed: 1': 'Health Clinic'})

# Collect Mean Values For Each Response Option
strongly_agree_mean_value = factors_affect_sat_values['Strongly agree'].mean()
agree_mean_value = factors_affect_sat_values['Agree'].mean()
neutral_mean_value = factors_affect_sat_values['Neutral'].mean()
disagree_mean_value = factors_affect_sat_values['Disagree'].mean()
strongly_disagree_mean_value = factors_affect_sat_values['Strongly disagree'].mean()

# Create a New Row With The Mean of Each Response Choice
mean_row_values = pd.DataFrame({
    'Health Clinic': ['All Health Clinics'], 
    'Strongly agree': [strongly_agree_mean_value], 
    'Agree': [agree_mean_value], 
    'Neutral': [neutral_mean_value], 
    'Disagree': [disagree_mean_value], 
    'Strongly disagree': [strongly_disagree_mean_value]
    })
print(mean_row_values)

# Select the relevant columns for the plot using index positions
plt.figure(figsize=(10, 6))
plt.bar(mean_row_values.index - 2/5, mean_row_values.iloc[:, 1], width = 0.2, label='Strongly agree', color='blue')
plt.bar(mean_row_values.index - 1/5, mean_row_values.iloc[:13, 2], width = 0.2, label='Agree', color='green')
plt.bar(mean_row_values.index - 0/5, mean_row_values.iloc[:13, 3], width = 0.2, label='Neutral', color='grey')
plt.bar(mean_row_values.index + 1/5, mean_row_values.iloc[:13, 4], width = 0.2, label='Disagree', color='orange')
plt.bar(mean_row_values.index + 2/5, mean_row_values.iloc[:13, 5], width = 0.2, label='Strongly disagree', color='red')

# Plotting
plt.xticks(mean_row_values.index, mean_row_values.iloc[:, 0])
plt.title('Overall, I am satisfied with the quality of service being provided via telemedicine')
plt.xlabel('Health Clinic')
plt.ylabel('Mean Percentage of Satisfaction Choice')

# Show the plot
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\bryce\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Users\bryce\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\bryce\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Strongly agree'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# In this graph, we can clearly see that on average, most patients agree with the prompt of being overall satisfied with the quality of service they received via telemedicine. Therefore, we can conclude that telemedicine is just as effective if not more effective than traditional in-person sessions for providing mental health care and therapy.

# %% [markdown]
# # Patients' motivations and satisfaction with telehealth Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

motivations_data = {
    'Motivation': ['Shorter/No Wait Time', 'Curiosity'],
    'All Patients': [56, 23],
    'Preferred Telehealth': [54, 25],
    'Liked Telehealth': [56, 23]
}

motivations_df = pd.DataFrame(motivations_data)

fig, ax = plt.subplots(figsize=(10, 6))
motivations_df.set_index('Motivation').plot(kind='bar', ax=ax, cmap='Set2')
plt.title('Motivations for Using Telehealth (%)')
plt.ylabel('Percentage (%)')
plt.xlabel('Motivation')  
plt.legend(title='Patient Group')  
plt.show()

# %% [markdown]
# The graph displays the motivations for using telehealth, specifically focusing on "Shorter/No Wait Time" and "Curiosity."
#
# -    Shorter/No Wait Time: The majority of all patients (56%) and those who preferred telehealth (54%) were motivated by the shorter or no wait time. This suggests that the convenience and efficiency of telehealth, especially in reducing waiting times, are significant factors contributing to patient satisfaction.
#  -    Curiosity: A notable portion of patients (23%) across all groups, including those who preferred telehealth (25%), expressed curiosity as a motivation. This may indicate a positive attitude towards exploring new technologies and healthcare delivery methods.

# %%
import matplotlib.pyplot as plt
import pandas as pd

satisfaction_data = {
    'Patient Group': ['All Patients', 'Preferred Telehealth', 'Liked Telehealth'],
    'Overall Understanding': [94, 97, 95],
    'Ease of Seeing Diagnostic Images': [95, 97, 96],
    'Quality of Health Care Received': [95, 98, 97],
    'Overall Satisfaction': [95, 98, 97]
}

satisfaction_df = pd.DataFrame(satisfaction_data)


fig, ax = plt.subplots(figsize=(10, 6))
satisfaction_df.set_index('Patient Group').plot(kind='bar', ax=ax, cmap='Set2')
plt.title('Satisfaction Scores (%)')
plt.ylabel('Satisfaction Score (%)')
plt.xlabel('Patient Group')
plt.legend(title='Satisfaction Aspect')
plt.show()

# %% [markdown]
# The satisfaction scores graph illustrates various aspects of patient satisfaction, including overall understanding, ease of seeing diagnostic images, quality of health care received, and overall satisfaction.
#
# - Overall Understanding: Patients, in general, reported high levels of understanding of the telehealth service (94%), with even higher satisfaction among those who preferred telehealth (97%). This suggests that telehealth is effective in conveying information to patients.
# - Ease of Seeing Diagnostic Images: The ease of viewing diagnostic images was rated high across all patient groups (95-97%). This indicates that telehealth platforms are successful in delivering visual information to patients.
# - Quality of Health Care Received: Patients reported high satisfaction with the quality of health care received, with 95-98% satisfaction. Telehealth seems to be as effective as traditional in-person sessions based on this measure.
# - Overall Satisfaction: The overall satisfaction scores also show high levels of satisfaction (95-98%) across all patient groups. This suggests that, according to patient surveys, telehealth is comparable to or even better than traditional in-person sessions.

# %%
import matplotlib.pyplot as plt
import pandas as pd

recommendation_data = {
    'Recommendation Level': ['Definitely Will', 'Probably Will'],
    'All Patients': [71, 27],
    'Preferred Telehealth': [95, 5],
    'Liked Telehealth': [73, 25]
}

recommendation_df = pd.DataFrame(recommendation_data)

fig, ax = plt.subplots(figsize=(10, 6))
recommendation_df.set_index('Recommendation Level').plot(kind='bar', ax=ax, cmap='Set2')
plt.title('Likelihood to Recommend Telehealth (%)')
plt.ylabel('Percentage (%)')
plt.xlabel('Recommendation Level')
plt.legend(title='Patient Group')
plt.show()

# %% [markdown]
# The likelihood to recommend telehealth is presented based on different recommendation levels.
#
# - Definitely Will Recommend: A significant portion of patients across all groups (71-95%) expressed that they would definitely recommend telehealth. This high level of endorsement indicates positive perceptions of telehealth effectiveness.
# - Probably Will Recommend: While the percentage is lower, a substantial portion still indicated a probability of recommending telehealth (5-27%). This adds to the overall positive outlook on telehealth since we had more people being conclusive about recommending verses being on the fence about recommending virtual health care

# %% [markdown]
# ### Overall Summary for Patient Motivation and Satisfaction
#
# In conclusion, the data analysis consistently points towards a positive perception of telehealth services for mental health care post-pandemic. Patients appear to find telehealth services effective, convenient, and satisfactory, as evidenced by their motivations, satisfaction scores, and willingness to recommend. The data presented here provides a snapshot of patient perspectives, supporting the hypothesis that telemedicine is a viable and effective alternative to traditional in-person mental health care sessions.

# %% [markdown]
# # Opinions about Telemedicine Experience Analysis

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Define the URLs for the datasets
opinions_url = "csv-corrected/Opinions about Telemedicine Experience-clean.csv"

# Read the datasets into pandas DataFrames
opinions_tele = pd.read_csv(opinions_url)

response_categories = ["Strongly agree", "Agree", "Neutral", "Disagree", "Strongly disagree"]

response_sum = {category: 0 for category in response_categories}

for index, row in opinions_tele.iterrows():
    if pd.notna(row["Unnamed: 0"]) and pd.notna(row["Unnamed: 1"]) and row["Unnamed: 1"] in response_categories:
        response_category = row["Unnamed: 1"]
        count = row["Count"]
        response_sum[response_category] += count

for index, row in opinions_tele.iterrows():
    if pd.notna(row["Unnamed: 0"]):
        current_question = row["Unnamed: 0"]
    elif pd.notna(row["Unnamed: 1"]) and row["Unnamed: 1"] in response_categories:
        response_category = row["Unnamed: 1"]
        count = row["Count"]
        response_sum[response_category] += count

# Create a pie chart
labels = response_sum.keys()
sizes = response_sum.values()

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

# Show the pie chart
plt.title("Distribution of Responses")
plt.show()

# %% [markdown]
# The chart exhibits five categories: "Strongly Agree," "Agree," "Neutral," "Disagree," and "Strongly Disagree," each corresponding to the percentage of respondents expressing their opinions. Notably, 14.7% of respondents strongly agreed, 39.1% agreed, 22.7% were neutral, 14.6% disagreed, and 9.0% strongly disagreed.
#
# This pie chart serves as a condensed and accessible visualization that captures the collective sentiment regarding telemedicine's efficacy in mental health care post-pandemic. The dominant positive responses, particularly the combination of "Strongly Agree" and "Agree" percentages, suggest an overall favorable perception of telemedicine for mental health care. The relatively lower percentages in the "Disagree" and "Strongly Disagree" categories indicate a less prevalent negative sentiment.
#
# The pie chart, illustrating the distribution of averaged responses on the effectiveness of telemedicine in providing mental health care and therapy post-pandemic, reveals a predominantly positive sentiment among respondents. With 14.7% strongly agreeing and 39.1% agreeing, a combined majority expresses satisfaction with telemedicine. The operational definition tying effectiveness to patient satisfaction scores aligns with this positive trend, indicating that a significant portion of individuals finds telemedicine a satisfactory and effective means of receiving mental health care. The lower percentages in the "Disagree" and "Strongly Disagree" categories suggest a relatively limited negative sentiment. These findings support the hypothesis that post-pandemic, telemedicine is perceived as an effective and well-received alternative to traditional in-person mental health sessions, emphasizing its potential role in the evolving landscape of healthcare delivery.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define the URLs for the datasets
opinions_url = "csv-corrected/Opinions about Telemedicine Experience-clean.csv"

# Read the datasets into a pandas DataFrame
df = pd.read_csv(opinions_url)

# Fill NaN values in 'Unnamed: 0' column with the appropriate question
df['Unnamed: 0'] = df['Unnamed: 0'].fillna(method='ffill')

# Pivot the DataFrame to make 'Unnamed: 1' values as columns
df_pivot = df.pivot(index='Unnamed: 0', columns='Unnamed: 1', values='Percent')

# Create a stack plot
fig, ax = plt.subplots(figsize=(10, 6))

# Stack plot using the transpose of the pivoted DataFrame
ax.stackplot(df_pivot.index, df_pivot.T, labels=df_pivot.columns)

# Set labels and title
ax.set_xlabel('Questions')
ax.set_ylabel('Percentage')
ax.set_title('Opinions about Telemedicine Experience')

# Show the legend
ax.legend(title='Opinion', bbox_to_anchor=(1.05, 1), loc='upper left')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# For the stack plot analysis, each question represented, and the stack plot visually illustrates the distribution of responses for each question. Notable outliers were identified in two specific questions: "I can see my healthcare provider as if we met in person" and "I do not receive adequate attention." In these instances, there is a distinctive shift from a predominant agreement to a more prevalent disagreement. It's important to note that the shift in the first question aligns with expectations for telehealth scenarios, where in-person visits might be less feasible. In contrast, the shift in the second question, indicating a higher disagreement about not receiving adequate attention, is noteworthy and suggests a negative sentiment regarding attention received during telehealth sessions.
#
# The stack plot visually emphasizes overwhelmingly positive views towards telehealth, with a majority expressing agreement and strong agreement. Notable outliers, particularly in the question about not receiving adequate attention, represent a positive deviation, indicating that respondents generally feel they are receiving the necessary attention during telehealth sessions. This positive shift supports the hypothesis that telemedicine effectively provides mental health care. Additionally, the presence of other outliers, such as the shift towards disagreement in the question about seeing healthcare providers as if in-person, adds nuance to the overall positive sentiment. Despite these outliers, the stack plot shows a large amount of questions being positive towards the telemedicine experience, reinforcing the broader acceptance and satisfaction with telehealth services post-pandemic. However, these outliers also provide opportunities for targeted improvements in certain areas could contribute to an even more positive and satisfactory patient experience, fulfilling the operational definition of the effectiveness of telemedicine in mental health care.

# %% [markdown]
# # Patient Satisfaction System Review

# %%
# Descriptive statistics of the patient satisfaction scores
descriptive_stats_sat = patient_sat['Patient satisfaction(%)'].describe()
descriptive_stats_sat
# Out:
# count     8.000000
# mean     73.300000
# std      17.275416
# min      43.400000
# 25%      67.725000
# 50%      79.450000
# 75%      82.175000
# max      94.900000
# Name: Patient satisfaction(%), dtype: float64

# %%
import numpy as np
import seaborn as sns
sns.set(context = 'talk', style='white')
#draw a histogram to show the distribution of patient satisfction scores
plt.figure(figsize=(10, 6))
sns.histplot(patient_sat['Patient satisfaction(%)'], kde=True, color = 'blue', bins=10)
plt.title('Distribution of Patient Satisfaction Scores')
plt.xlabel('Patient Satisfaction (%)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# This plot presents the distribution of patient satisfaction scores. The data is skewed to left slightly with scores ranging broadly.Notably, the majority of patient satisfaction scores exceed 70%, with a significant concentration around the 80% mark. This suggests a generally high level of effectiveness of telemedicine services, as perceived by the patients

# %%
#reshape the dataset to transform the dataset so that each row corresponds to a specific telemedicine tool and its associated usage percentage.
reshaped_data = patient_sat.melt(id_vars=['Name of author', 'Title of study', 'Year', 'Study design', 'Age (years)', 'Sample size', 'Country/state', 'Outcome measures', 'Patient satisfaction(%)'],
                        value_vars=['Voice Call(%)', 'Video Call(%)', 'Messaging/email(%)', 'Telemedicine app(%)'],
                        var_name='Telemedicine tool', value_name='Percentage')
#draw the barplot to show communication tools in telemedicine by Country/State
plt.figure(figsize=(12, 8))
sns.barplot(data = reshaped_data, x ='Telemedicine tool', y='Percentage',hue = 'Country/state', palette='pastel')
plt.title('Comparison of Communication Tools in Telemedicine')
plt.xlabel('Telemedicine Tool')
plt.ylabel('Average Usage Percentage')
plt.legend(title='Country/state',bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
#reshape the dataset to transform the dataset so that each row corresponds to a specific telemedicine tool and its associated usage percentage.
reshaped_data = patient_sat.melt(id_vars=['Name of author', 'Title of study', 'Year', 'Study design', 'Age (years)', 'Sample size', 'Country/state', 'Outcome measures', 'Patient satisfaction(%)'],
                        value_vars=['Voice Call(%)', 'Video Call(%)', 'Messaging/email(%)', 'Telemedicine app(%)'],
                        var_name='Telemedicine tool', value_name='Percentage')
#draw the barplot to show communication tools in telemedicine by Country/State
plt.figure(figsize=(12, 8))
sns.barplot(data = reshaped_data, x ='Telemedicine tool', y='Percentage',hue = 'Country/state', palette='pastel')
plt.title('Comparison of Communication Tools in Telemedicine')
plt.xlabel('Telemedicine Tool')
plt.ylabel('Average Usage Percentage')
plt.legend(title='Country/state',bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# Two barplots above shows a comprehensive overview of telemedicine tool usage across different regions and age groups. The first plot reveals significant regional variations in the preference for telemedicine tools like voice calls, video calls, messaging/email, and apps, indicating diverse technological adoption and healthcare practices in different countries or states. The second plot focuses on the year of study, revealing how the preferences for telemedicine tools have evolved over time. in addition to video call whos usage decreases over time. The rest of telemedicine tools all increases in their usage from 2021 to 2022. Among them, messaging/email has the highest growth rate.

# %%
# Select only the numeric columns for correlation
numeric_columns = patient_sat.select_dtypes(include=[np.number])
#draw the correlation matrix
correlation_matrix = numeric_columns.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='Spectral')
plt.title('Correlation Matrix of Variables')
plt.show()

# %% [markdown]
# This correlation matrix provides valuable insights into the relationships between different aspects of telemedicine services. Specifically, there is a strong positive relationship (0,8) between patient satisfaction scores and video calls, indicating that patients with high usage of video calls have high satisfaction scores. By contrast, the correlation between telemedicine app and patient satisfaction is loose even though it is positive, indicating there might be no strong relationship between those two variables. Adnd other telemedicine tools, like voice call and messaginng/emails have negative correlation with patient satisfaction (-0.37 and -0.42 respectively), indicating that that higher usage of these tools might be associated with lower patient satisfaction scores. These findings underscore the varying impacts of different telemedicine tools on patient satisfaction, highlighting the preference for video calls over other forms of communication in the context of telemedicine.

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# - Some privacy issues that come up with the data that we proposed are the exposure of private conversations between the patient and the therapist. Privacy shouldn’t be a big concern, as the practicing therapists who would provide the data will have to adhere to HIPAA.
# - One source of bias would be the patients’ own preferences. When given the choice, some patients might prefer to receive their care one way or another. This will lead to them rating their preferred method care to be more effective. Some other potential biases in our dataset is the demographic/population being sampled, and we do not know the methods of how the data from the dataset was created/collected. Too often, WEIRD (Western, Educated, Industrial, Rich, Democracies) populations are taken. This can affect the efficacy of our data as it is heavily biased to a certain population. Additionally, we do not know if the people who created the data from the dataset had some sort of ulterior motive or inherent bias against the participants involved.
# - Some of the ways we will set out to detect these specific biases for commuting our analysis is by having participants experience both forms of delivering mental health care and therapy, check for a description of the characteristics of the participants involved in the data, and analyze the methodology used during the creation of the data.
# - Some issues related to our data that are potentially problematic in terms of equitable impact is that our data is not representative of the population of the United States as a whole
# - We will negate privacy concerns by using a dataset where the patients voluntarily submit their feedback.
# - Some of the negative consequences that could arise during and after the project are Inaccurate Representations. Specifically, if biases in the dataset are not adequately identified and addressed, the outcomes may provide inaccurate representations of the effectiveness of telemedicine. This could lead to misguided conclusions and potentially influence decision-making in mental health care policies and practices.

# %% [markdown]
# # Team Expectations

# %% [markdown]
# * Team Expectation 1: Join group calls within an hour of the scheduled meeting time.
# * Team Expectation 2: Plan meetings ahead of time
# * Team Expectation 3: Each team member should contribute equally to the project
# * Team Expectation 4: Be respectful of people’s time and responsive by communicating effectively to the group as a whole
# * Team Expectation 5: Utilize each other’s strengths to work on the project more efficiently.

# %% [markdown]
# # Project Timeline Proposal

# %% [markdown]
# | Meeting Date  | Meeting Time| Completed Before Meeting  | Discuss at Meeting |
# |---|---|---|---|
# | 10/22  |  6 PM | Read & Think about COGS 108 expectations; brainstorm topics/questions  | Discuss and complete the project review |
# | 11/1  |  6 PM |  Do background research on topic | Discuss and complete the Project Proposal |
# | 11/15  | 6 PM  | Edit, finalize, and submit proposal; Search for datasets  | Discuss and complete the Data Checkpoint   |
# | 11/28  | 7 PM  | Import & Wrangle Data; EDA | Discuss and complete the EDA Checkpoint   |
# | 12/6  | 6 PM  | Finalize wrangling/EDA; Begin Analysis | Continue editing and revising final project |
# | 12/13  | 6 PM  | Complete analysis; Draft results/conclusion/discussion | Finalize Final Project |
# | 12/13  | Before 11:59 PM  | NA | Turn in Final Project & Group Project Surveys |
